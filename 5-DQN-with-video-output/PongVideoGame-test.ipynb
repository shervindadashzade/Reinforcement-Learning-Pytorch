# %% [markdown]
# ## Preparing the Environment

# %%
# !pip install --upgrade gym==0.19.0
# !pip install atari-py
# Out:
# Requirement already up-to-date: gym==0.19.0 in /home/shervin/.local/lib/python3.8/site-packages (0.19.0)
# Requirement already satisfied, skipping upgrade: cloudpickle<1.7.0,>=1.2.0 in /home/shervin/.local/lib/python3.8/site-packages (from gym==0.19.0) (1.6.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.18.0 in /home/shervin/.local/lib/python3.8/site-packages (from gym==0.19.0) (1.22.1)
# Requirement already satisfied: atari-py in /home/shervin/.local/lib/python3.8/site-packages (0.2.9)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from atari-py) (1.14.0)
# Requirement already satisfied: numpy in /home/shervin/.local/lib/python3.8/site-packages (from atari-py) (1.22.1)

# %%
# !wget http://www.atarimania.com/roms/Roms.rar
# Out:
# --2023-02-08 19:39:11--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 503 Service Unavailable
# 2023-02-08 19:39:11 ERROR 503: Service Unavailable.

# %%
# !mkdir roms

# %%
# !unrar x Roms.rar roms/
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from Roms.rar
#
# Creating    roms/ROMS                                                 OK
# Extracting  roms/ROMS/128 in 1 Game Select ROM (Unknown) ~.bin           0  OK
# Extracting  roms/ROMS/2 in 1 - Chess, Othello (Atari) (Prototype).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Cavern Blaster, City War (1992) (HES) (773-867) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Challenge, Surfing (1990) (HES) (771-333) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Dolphin, Oink (1990) (HES) (771-341) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Dolphin, Pigs n' Wolf (1990) (HES) (771-341) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Dungeon Master, Creature Strike (1992) (HES) (773-891) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Hoppy, Alien Force (1992) (HES) (773-875) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Moto-Cross, Boom Bang (1990) (HES) (701-157) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Space Voyage, Fire Alert (1992) (HES) (773-883) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Star Warrior, Frogger (1990) (HES) (771-422) (PAL).bin     0  OK
# Extracting  roms/ROMS/2 Pak Special - Wall Defender, Planet Patrol (1990) (HES) (771-406) (PAL).bin     0  OK
# Extracting  roms/ROMS/208 in 1 Game Select ROM (Unknown) (PAL) ~.bin     0  OK
# Extracting  roms/ROMS/3-D Genesis (1983) (Amiga - Video Soft, Jerry Lawson, Dan McElroy) (Prototype) ~.bin     0  OK
# Extracting  roms/ROMS/3-D Ghost Attack (1983) (Amiga - Video Soft, Michael K. Glass, Jerry Lawson) (Prototype) ~.bin     0  OK
# Extracting  roms/ROMS/3-D Havoc (1983) (Amiga - Video Soft, Frank Ellis, Jerry Lawson) (2110) (Prototype) ~.bin     0  OK
# Extracting  roms/ROMS/3-D Tic-Tac-Toe (1980) (Atari, Carol Shaw - Sears) (CX2618 - 49-75123) ~.bin     0  OK
# Extracting  roms/ROMS/3-D Tic-Tac-Toe (1980) (Atari, Carol Shaw) (CX2618, CX2618P) (PAL).bin     0  OK
# Extracting  roms/ROMS/3-D Zapper (12-15-82) (U.S. Games Corporation - JWDA, Todd Marshall) (Prototype) ~.bin     0  OK
# Extracting  roms/ROMS/3-D Zapper (U.S. Games Corporation - JWDA, Todd Marshall) (Prototype).bin     0  OK
# Extracting  roms/ROMS/32 in 1 Console ROM (02-10-1989) (Atari) (Prototype) (PAL).bin     0  OK
# Extracting  roms/ROMS/32 in 1 Game Cartridge (1988) (Atari) (CX26163P) (PAL).bin       1  OK
# Extracting  roms/ROMS/3D Tic-Tac-Toe (32 in 1) (1988) (Atari, Carol Shaw) (CX26163P) (PAL).bin     1  OK
# Extracting  roms/ROMS/4 Game in One - Ice Hockey, Phantom UFO, Spy Vs. Spy, Cosmic Avenger (1983) (Bit Corporation) (PAL).bin     1  OK
# Extracting  roms/ROMS/4 Game in One - Rodeo Champ, Open Sesame, Bobby Is Going Home, Festival (1983) (Bit Corporation) (P460) (PAL).bin     1  OK
# Extracting  roms/ROMS/4 in 1 - Canyon Bomber, Home Run, Night Driver, Sky Diver (02-19-1987) (Atari) (CX26137) (Prototype).bin     1  OK
# Extracting  roms/ROMS/8 in 1 (Supergames 8 in 1) (01-16-92) (Atari) (CX26193) (Prototype).bin     1  OK
# Extracting  roms/ROMS/========  ROM HUNTER'S 1977-1992 VCS ROMS COLLECTION V18  ========.txt     1  OK
# Extracting  roms/ROMS/A-Team, The (AKA Saboteur) (03-30-1984) (Atari, Jerome Domurat, Howard Scott Warshaw) (CX26133) (Prototype).bin     1  OK
# Extracting  roms/ROMS/A-Team, The (AKA Saboteur) (05-08-1984) (Atari, Jerome Domurat, Howard Scott Warshaw) (CX26133) (Prototype).bin     1  OK
# Extracting  roms/ROMS/Acid Drop (1992) (Salu, Dennis M. Kiss) (460758) (PAL) ~.bin     1  OK
# Extracting  roms/ROMS/Action Man - Action Force (AKA G.I. Joe - Cobra Strike) (Paddle) (1983) (Parker Brothers, John Emerson) (931511) (PAL).bin     1  OK
# Extracting  roms/ROMS/Actionauts (Microbots) (1984-2008) (Imagic - Advanced Program Technology, Rob Fulop) ~.bin     1  OK
# Extracting  roms/ROMS/Activision Decathlon, The (1983) (Activision, David Crane) (AG-930-04, AZ-030) [fixed] ~.bin     1  OK
# Extracting  roms/ROMS/Activision Decathlon, The (1983) (Activision, David Crane) (AG-930-04, AZ-030) ~.bin     1  OK
# Extracting  roms/ROMS/Activision Decathlon, The (1983) (Activision, David Crane) (EAZ-030) (SECAM).bin     1  OK
# Extracting  roms/ROMS/Activision Decathlon, The - Zehnkampf (1983) (Activision, David Crane - Ariola) (EAZ-030, EAZ-030-04B, EAZ-030-04I - 711 030-725) (PAL).bin     1  OK
# Extracting  roms/ROMS/Adventure (1980) (Atari, Warren Robinett - Sears) (CX2613 - 49-75154) ~.bin     1  OK
# Extracting  roms/ROMS/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin     1  OK
# Extracting  roms/ROMS/Adventures of TRON (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Hal Finney, Glenn Hightower, Peter Kaminski) (MT4317) ~.bin     1  OK
# Extracting  roms/ROMS/Adventures on GX-12 (AKA Adventures of TRON) (1988) (Telegames) (4317 A009) (PAL).bin     1  OK
# Extracting  roms/ROMS/Air Raid (1982) (Men-A-Vision) (PAL) ~.bin         1  OK
# Extracting  roms/ROMS/Air Raiders (Air Battle) (1983) (M Network - INTV - APh Technological Consulting, Larry Zwick) (MT5861) ~.bin     1  OK
# Extracting  roms/ROMS/Air Raiders (Hack) (32 in 1) (Bit Corporation) (R320).bin     1  OK
# Extracting  roms/ROMS/Air Raiders (Unknown) (PAL).bin                    1  OK
# Extracting  roms/ROMS/Air-Sea Battle (32 in 1) (1988) (Atari, Larry Kaplan) (CX26163P) (PAL).bin     1  OK
# Extracting  roms/ROMS/Air-Sea Battle (Hack) (Unknown) (4K).bin           1  OK
# Extracting  roms/ROMS/Air-Sea Battle - Air Sea Battle (Anti-Aircraft) (1977) (Atari, Larry Kaplan) (CX2602, CX2602P) (PAL).bin     1  OK
# Extracting  roms/ROMS/Air-Sea Battle - Air Sea Battle - Target Fun (Anti-Aircraft) (1977) (Atari, Larry Kaplan - Sears) (CX2602 - 99802, 6-99802, 49-75102) ~.bin     1  OK
# Extracting  roms/ROMS/Airlock (1982) (Data Age) (DA1004) (Prototype).bin     1  OK
# Extracting  roms/ROMS/Airlock (1982) (Data Age) (DA1004) ~.bin           1  OK
# Extracting  roms/ROMS/Airlock (1983) (Gameworld) (133-004) (PAL).bin     1  OK
# Extracting  roms/ROMS/Alices Abenteuer - Lilly Adventure (1983) (Quelle - Otto Versand) (732.273 8 - 600273, 781644) (PAL).bin     1  OK
# Extracting  roms/ROMS/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin     1  OK
# Extracting  roms/ROMS/Alien (CCE).bin                                    2  OK
# Extracting  roms/ROMS/Alien's Return (AKA Go Go Home) (1983) (ITT Family Games) (554-33 391) (PAL).bin     2  OK
# Extracting  roms/ROMS/Alligator People (1983) (20th Century Fox Video Games, John Russell) (Prototype) ~.bin     2  OK
# Extracting  roms/ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (05-05-1983) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) (Prototype).bin     2  OK
# Extracting  roms/ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (06-03-1983) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) (Prototype) (PAL).bin     2  OK
# Extracting  roms/ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (12-22-1982) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) (Prototype).bin     2  OK
# Extracting  roms/ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (1983) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) (PAL).bin     2  OK
# Extracting  roms/ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (1983) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) ~.bin     2  OK
# Extracting  roms/ROMS/Amidar (1982) (Parker Brothers, Ed Temple) (931504) (PAL).bin     2  OK
# Extracting  roms/ROMS/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin     2  OK
# Extracting  roms/ROMS/Amidar (Hack) (32 in 1) (Bit Corporation) (R320).bin     2  OK
# Extracting  roms/ROMS/AndroMan on the Moon (1984) (Androbot - Western Technologies, Michael Case, Lenny Carlson) (Prototype) ~.bin     2  OK
# Extracting  roms/ROMS/Angeln I (AKA Fishing Derby) (Videospielkassette - Ariola) (PGP237) (PAL).bin     2  OK
# Extracting  roms/ROMS/Angriff der Luftflotten - Paris Attack (AKA M.A.D.) (1983) (Quelle - Otto Versand) (495.463 2 - 746381) (PAL).bin     2  OK
# Extracting  roms/ROMS/Ant Party (AKA Cosmic Swarm) (32 in 1) (1988) (Atari) (CX26163P) (PAL).bin     2  OK
# Extracting  roms/ROMS/Apples and Dolls (AKA Open, Sesame!) (CCE).bin     2  OK
# Extracting  roms/ROMS/Aquatak (AKA Skindiver) (1983) (John Sands Electronics) (JS145C) (PAL).bin     2  OK
# Extracting  roms/ROMS/Aquaventure (CCE).bin                              2  OK
# Extracting  roms/ROMS/Aquaventure (Sea Sentinel) (08-12-1983) (Atari, Tod Frye, Gary Shannon) (Prototype) ~.bin     2  OK
# Extracting  roms/ROMS/Arkyology (1983) (Sparrow - Enter-Tech, Rick Harris, George Hefner, Paul Walters, Barbara Ultis) (Prototype) ~.bin     2  OK
# Extracting  roms/ROMS/Armor Ambush (1988) (Telegames) (PAL).bin          2  OK
# Extracting  roms/ROMS/Armor Ambush (Tank Battle) (1982) (M Network - INTV - APh Technological Consulting, Hal Finney) (MT5661) ~.bin     2  OK
# Extracting  roms/ROMS/Artillery Duel (1983) (Xonox - K-Tel Software - Action Graphics, Michael Schwartz, David Thiel) (6230, 7210, 06004, 99004) (PAL).bin     2  OK
# Extracting  roms/ROMS/Artillery Duel (1983) (Xonox - K-Tel Software - Action Graphics, Michael Schwartz, David Thiel) (6230, 7210, 06004, 99004) ~.bin     2  OK
# Extracting  roms/ROMS/Ases do Ar (AKA Sky Jinks) (Dismac).bin            2  OK
# Extracting  roms/ROMS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281) (PAL).bin     2  OK
# Extracting  roms/ROMS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin     2  OK
# Extracting  roms/ROMS/Asterix (AKA Taz) (08-01-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype) (PAL).bin     2  OK
# Extracting  roms/ROMS/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696) (PAL).bin     2  OK
# Extracting  roms/ROMS/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696).bin     2  OK
# Extracting  roms/ROMS/Asteroid Belt (AKA Asteroid Fire) (1983) (Suntek) (SS-029) (PAL).bin     2  OK
# Extracting  roms/ROMS/Asteroid Fire (1983) (Home Vision - Gem International Corporation - VDI) (VCS83111) (PAL) ~.bin     2  OK
# Extracting  roms/ROMS/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin     2  OK
# Extracting  roms/ROMS/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) ~.bin     2  OK
# Extracting  roms/ROMS/Asteroids (1981) (Atari, Brad Stewart) (CX2649, CX2649P) (PAL) [no copyright].bin     2  OK
# Extracting  roms/ROMS/Asteroids (1981) (Atari, Brad Stewart) (CX2649, CX2649P) (PAL).bin     2  OK
# Extracting  roms/ROMS/Astro Attack (AKA Time Warp) (1983) (Goliath - Hot Shot) (83-214) (PAL).bin     2  OK
# Extracting  roms/ROMS/Astro Chase (10-25-1983) (Parker Brothers - First Star Software, Alex Leavens) (Prototype) ~.bin     2  OK
# Extracting  roms/ROMS/Astroblast (Paddle) (1982) (M Network - INTV - APh Technological Consulting, Hal Finney) (MT5666) [fixed] ~.bin     2  OK
# Extracting  roms/ROMS/Astroblast (Paddle) (1982) (M Network - INTV - APh Technological Consulting, Hal Finney) (MT5666) ~.bin     2  OK
# Extracting  roms/ROMS/Astroblast (Paddle) (1988) (Telegames) (PAL).bin     2  OK
# Extracting  roms/ROMS/Astrowar (1983) (Goliath) (2) (PAL).bin            2  OK
# Extracting  roms/ROMS/Astrowar (Astrobattle) (Dimax - Sinmax) (SM8002) (PAL) ~.bin     2  OK
# Extracting  roms/ROMS/Astrowar (Unknown).bin                             2  OK
# Extracting  roms/ROMS/Atari VCS Point-of-Purchase ROM (1982) (Atari) ~.bin     2  OK
# Extracting  roms/ROMS/Atari Video Cube (Atari Cube, Video Cube) (1983) (Atari - GCC, Josh Littlefield, Douglas B. Macrae) (CX2670) ~.bin     2  OK
# Extracting  roms/ROMS/Atlantis (1983) (CCE) (C-832) [a].bin              2  OK
# Extracting  roms/ROMS/Atlantis (1983) (CCE) (C-832).bin                  2  OK
# Extracting  roms/ROMS/Atlantis (1983) (Digitel).bin                      2  OK
# Extracting  roms/ROMS/Atlantis (1983) (Dynacom).bin                      2  OK
# Extracting  roms/ROMS/Atlantis (Dactari - Milmar).bin                    2  OK
# Extracting  roms/ROMS/Atlantis (Fotomania).bin                           2  OK
# Extracting  roms/ROMS/Atlantis (Hack) (32 in 1) (Bit Corporation) (R320).bin     2  OK
# Extracting  roms/ROMS/Atlantis (Hack) (Unknown) (PAL) [a].bin            2  OK
# Extracting  roms/ROMS/Atlantis (Hack) (Unknown) (PAL).bin                2  OK
# Extracting  roms/ROMS/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin     2  OK
# Extracting  roms/ROMS/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-2A, IA3203P, EIX-010-04I) (PAL).bin     3  OK
# Extracting  roms/ROMS/Atlantis II (1982) (Imagic, Dennis Koble) (720103-1A, IA3203).bin     3  OK
# Extracting  roms/ROMS/Atom Smasher (1984) (Video Soft) (Prototype) [stack pointer fix] ~.bin     3  OK
# Extracting  roms/ROMS/Atom Smasher (1984) (Video Soft) (Prototype).bin     3  OK
# Extracting  roms/ROMS/Aufruhr im Zoo (AKA Pumuckl at the Zoo) (1983) (Quelle) (719.694 2) (PAL).bin     3  OK
# Extracting  roms/ROMS/Autorennen (AKA Grand Prix) (Videospielkassette - Ariola) (PGP232) (PAL).bin     3  OK
# Extracting  roms/ROMS/Bachelor Party (Paddle) (1982) (Mystique - American Multiple Industries, Joel H. Martin) (1002) ~.bin     3  OK
# Extracting  roms/ROMS/Bachelor Party (Paddle) (1982) (PlayAround - JHM) (205).bin     3  OK
# Extracting  roms/ROMS/Bachelorette Party (AKA Bachelor Party) (Paddle) (1982) (PlayAround - JHM) (202).bin     3  OK
# Extracting  roms/ROMS/Backgammon (Paddle) (1979) (Atari, Craig Nelson - Sears) (CX2617 - 49-75183) ~.bin     3  OK
# Extracting  roms/ROMS/Backgammon (Paddle) (1979) (Atari, Craig Nelson) (CX2617, CX2617P) (PAL).bin     3  OK
# Extracting  roms/ROMS/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin     3  OK
# Extracting  roms/ROMS/Bank Heist (Hack) (32 in 1) (Bit Corporation) (R320).bin     3  OK
# Extracting  roms/ROMS/Bank Heist (Unknown) (PAL) [a].bin                 3  OK
# Extracting  roms/ROMS/Bank Heist (Unknown) (PAL).bin                     3  OK
# Extracting  roms/ROMS/Barnstorming (1982) (Activision, Steve Cartwright) (AX-013) ~.bin     3  OK
# Extracting  roms/ROMS/Barnstorming (CCE).bin                             3  OK
# Extracting  roms/ROMS/Barnstorming (Unknown) (PAL) [a].bin               3  OK
# Extracting  roms/ROMS/Barnstorming (Unknown) (PAL).bin                   3  OK
# Extracting  roms/ROMS/Barnstorming - Die tollkeuhnen Flieger (1982) (Activision, Steve Cartwright - Ariola) (EAX-013, PAX-013 - 711 013-720) (PAL).bin     3  OK
# Extracting  roms/ROMS/Base Attack (1983) (Home Vision - Gem International Corporation - VDI) (VCS83113) (PAL) ~.bin     3  OK
# Extracting  roms/ROMS/Base Attack (Hack) (Unknown).bin                   3  OK
# Extracting  roms/ROMS/Baseball (AKA Super Challenge Baseball) (1988) (Telegames) (5665 A016) (PAL).bin     3  OK
# Extracting  roms/ROMS/Baseball (AKA Super Challenge Baseball) (1988) (Telegames) (5665 A016).bin     3  OK
# Extracting  roms/ROMS/Basic Math (Math Pack) (1977) (Atari, Gary Palmer) (CX2661) (PAL).bin     3  OK
# Extracting  roms/ROMS/Basic Math (Unknown) (PAL).bin                     3  OK
# Extracting  roms/ROMS/Basic Math - Math (Math Pack) (1977) (Atari, Gary Palmer - Sears) (CX2661 - 99808, 6-99808) ~.bin     3  OK
# Extracting  roms/ROMS/BASIC Programming (Keyboard Controller) (1979) (Atari, Warren Robinett) (CX2620) ~.bin     3  OK
# Extracting  roms/ROMS/BASIC Programming (Keyboard Controller) (1979) (Atari, Warren Robinett) (CX2620, CX2620P) (PAL).bin     3  OK
# Extracting  roms/ROMS/Basketball (1978) (Atari, Alan Miller - Sears) (CX2624 - 6-99826, 49-75113) ~.bin     3  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS                                              OK
# Creating    roms/HC ROMS/BY ALPHABET                                  OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET/A-G                              OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET/H-R                              OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET/S-Z                              OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET (PAL)                            OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET (PAL)/A-G                        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET (PAL)/H-R                        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY ALPHABET (PAL)/S-Z                        OK
# Creating    roms/HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY                                   OK
# Creating    roms/HC ROMS/BY COMPANY/20th Century Fox Video Games      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Absolute Entertainment            OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Activision                        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Advanced Program Technology       OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/American Videogame                OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Amiga                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Answer Software Corporation       OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Apollo - Games by Apollo          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Atari - Sears                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Avalon Hill                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Camelot - Johnson & Johnson       OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/CBS Electronics                   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/CCE                               OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Coleco                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/CommaVid - Computer Magic         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Control Video Corporation         OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Data Age                          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Datatech Enterprises Co           OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Dimax - Sinmax                    OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Dynacom                           OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Epyx                              OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Exus Corporation                  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/First Star Software               OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Funvision - Fund. International Co  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Gammation                         OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/HES                               OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Home Vision - GEM International Corp  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/HomeComputer Software Co          OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Imagic                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Inspirational Video Concepts      OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/James Wickstead Design Associates  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Konami                            OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/M Network - Mattel Electronics    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Men-A-Vision                      OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Milton Bradley Company            OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Multivision                       OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Mystique - American Multiple Industries - JHM  OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Mythicon                          OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Other                             OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Parker Brothers                   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Personal Games Company            OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Probe 2000 - North American Philips Consumer Electronics Corporation  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Puzzy - Bit Corporation           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/QDI - Selchow & Righter           OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Salu                              OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Sancho - Tang's Electronic Co     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/SEGA                              OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Simage                            OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Skill Screen Games                OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Spectravision - Spectravideo      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Starpath Corporation - Arcadia Corporation  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Sunrise Software                  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Syncro, Inc                       OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/TechnoVision                      OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Telegames                         OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Telesys                           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Tigervision                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/U.S. Games Corporation            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/UA Limited                        OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Ultravision                       OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Universal Gamex Corporation       OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/VentureVision                     OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Video Gems                        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Video Soft                        OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Western Technologies              OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Wizard Video Games                OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/Xonox - K-Tel Software            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY/ZiMAG - Emag - Vidco              OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)                             OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/20th Century Fox Video Games  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/20th Century Fox Video Games/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Absolute Entertainment      OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Activision                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Activision/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Advanced Program Technology (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/American Videogame (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Amiga                       OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Amiga/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Answer Software Corporation (NTSC ONLY)  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Apollo - Games by Apollo    OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Apollo - Games by Apollo/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Atari - Sears               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Atari - Sears/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Avalon Hill (NTSC ONLY)     OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Camelot - Johnson & Johnson (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Carrere Video               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/CBS Electronics             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/CBS Electronics/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/CCE (NTSC ONLY)             OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Coleco (NTSC ONLY)          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/CommaVid - Computer Magic   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/CommaVid - Computer Magic/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Control Video Corporation (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Data Age (NTSC ONLY)        OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Datatech Enterprises Co (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Dimax - Sinmax              OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Dynacom (NTSC ONLY)         OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Epyx                        OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Exus Corporation (NTSC ONLY)  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/First Star Software         OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/First Star Software/REMAINING NTSC ORIGINALS  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Funvision - Fund. International Co  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Gakken - Konami             OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Gameworld                   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Gammation (NTSC ONLY)       OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/HES                         OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Home Vision - GEM International Corp  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/HomeComputer Software Co (NTSC ONLY)  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Imagic                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Imagic/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Inspirational Video Concepts (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/James Wickstead Design Associates  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/James Wickstead Design Associates/REMAINING NTSC ORIGINALS  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/M Network - Mattel Electronics (NTSC ONLY)  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Men-A-Vision                OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Milton Bradley Company (NTSC ONLY)  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Multivision (NTSC ONLY)     OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Mystique - American Multiple Industries - JHM  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Mystique - American Multiple Industries - JHM/REMAINING NTSC ORIGINALS  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Mythicon (NTSC ONLY)        OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Other                       OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Other/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Parker Brothers             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Parker Brothers/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Personal Games Company (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/PlayAround - JHM            OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/PlayAround - JHM/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Probe 2000 - North American Philips Consumer Electronics Corporation (NTSC ONLY)  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Puzzy - Bit Corporation     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/QDI - Selchow & Righter (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Quelle                      OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Salu                        OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Sancho - Tang's Electronic Co  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/SEGA                        OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/SEGA/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Simage (NTSC ONLY)          OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Skill Screen Games (NTSC ONLY)  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Spectravision - Spectravideo  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Spectravision - Spectravideo/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Starpath Corporation - Arcadia Corporation  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Starpath Corporation - Arcadia Corporation/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Suntek - Sunteck Co         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Syncro, Inc (NTSC ONLY)     OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/TechnoVision                OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Telegames                   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Telesys                     OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Telesys/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Tigervision                 OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Tigervision/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/U.S. Games Corporation      OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/U.S. Games Corporation/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/UA Limited (NTSC ONLY)      OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Ultravision                 OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Universal Gamex Corporation  OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/VentureVision (NTSC ONLY)   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Video Gems                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Video Soft (NTSC ONLY)      OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Western Technologies (NTSC ONLY)  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Wizard Video Games (NTSC ONLY)  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Xonox - K-Tel Software      OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/Xonox - K-Tel Software/REMAINING NTSC ORIGINALS  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/BY COMPANY (PAL)/ZiMAG - Emag - Vidco (NTSC ONLY)  OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/NTSC VERSIONS OF PAL ORIGINALS               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# !python3 -m atari_py.import_roms roms
# Out:
# copying assault.bin from roms/HC ROMS/NTSC VERSIONS OF PAL ORIGINALS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/assault.bin
# copying gopher.bin from roms/HC ROMS/BY ALPHABET/A-G/Gopher.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/gopher.bin
# copying centipede.bin from roms/HC ROMS/BY ALPHABET/A-G/Centipede.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/centipede.bin
# copying donkey_kong.bin from roms/HC ROMS/BY ALPHABET/A-G/Donkey Kong.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/donkey_kong.bin
# copying atlantis.bin from roms/HC ROMS/BY ALPHABET/A-G/Atlantis.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/atlantis.bin
# copying freeway.bin from roms/HC ROMS/BY ALPHABET/A-G/Freeway.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/freeway.bin
# copying alien.bin from roms/HC ROMS/BY ALPHABET/A-G/Alien.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/alien.bin
# copying fishing_derby.bin from roms/HC ROMS/BY ALPHABET/A-G/Fishing Derby.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/fishing_derby.bin
# copying crazy_climber.bin from roms/HC ROMS/BY ALPHABET/A-G/Crazy Climber.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/crazy_climber.bin
# copying boxing.bin from roms/HC ROMS/BY ALPHABET/A-G/Boxing.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/boxing.bin
# copying bowling.bin from roms/HC ROMS/BY ALPHABET/A-G/Bowling.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/bowling.bin
# copying enduro.bin from roms/HC ROMS/BY ALPHABET/A-G/Enduro.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/enduro.bin
# copying berzerk.bin from roms/HC ROMS/BY ALPHABET/A-G/Berzerk.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/berzerk.bin
# copying beam_rider.bin from roms/HC ROMS/BY ALPHABET/A-G/Beamrider.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/beam_rider.bin
# copying galaxian.bin from roms/HC ROMS/BY ALPHABET/A-G/Galaxian.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/galaxian.bin
# copying frogger.bin from roms/HC ROMS/BY ALPHABET/A-G/Frogger.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/frogger.bin
# copying elevator_action.bin from roms/HC ROMS/BY ALPHABET/A-G/Elevator Action (Prototype).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/elevator_action.bin
# copying chopper_command.bin from roms/HC ROMS/BY ALPHABET/A-G/Chopper Command.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/chopper_command.bin
# copying gravitar.bin from roms/HC ROMS/BY ALPHABET/A-G/Gravitar.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/gravitar.bin
# copying carnival.bin from roms/HC ROMS/BY ALPHABET/A-G/Carnival.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/carnival.bin
# copying amidar.bin from roms/HC ROMS/BY ALPHABET/A-G/Amidar.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/amidar.bin
# copying asteroids.bin from roms/HC ROMS/BY ALPHABET/A-G/Asteroids [no copyright].bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/asteroids.bin
# copying bank_heist.bin from roms/HC ROMS/BY ALPHABET/A-G/Bank Heist.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/bank_heist.bin
# copying battle_zone.bin from roms/HC ROMS/BY ALPHABET/A-G/Battlezone.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/battle_zone.bin
# copying air_raid.bin from roms/HC ROMS/BY ALPHABET/A-G/Air Raid (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/air_raid.bin
# copying frostbite.bin from roms/HC ROMS/BY ALPHABET/A-G/Frostbite.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/frostbite.bin
# copying breakout.bin from roms/HC ROMS/BY ALPHABET/A-G/Breakout - Breakaway IV.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/breakout.bin
# copying double_dunk.bin from roms/HC ROMS/BY ALPHABET/A-G/Double Dunk.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/double_dunk.bin
# copying demon_attack.bin from roms/HC ROMS/BY ALPHABET/A-G/Demon Attack.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/demon_attack.bin
# copying defender.bin from roms/HC ROMS/BY ALPHABET/A-G/Defender.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/defender.bin
# copying kung_fu_master.bin from roms/HC ROMS/BY ALPHABET/H-R/Kung-Fu Master.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/kung_fu_master.bin
# copying road_runner.bin from patched version of roms/HC ROMS/BY ALPHABET/H-R/Road Runner.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/road_runner.bin
# copying ms_pacman.bin from roms/HC ROMS/BY ALPHABET/H-R/Ms. Pac-Man.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/ms_pacman.bin
# copying robotank.bin from roms/HC ROMS/BY ALPHABET/H-R/Robot Tank.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/robotank.bin
# copying private_eye.bin from roms/HC ROMS/BY ALPHABET/H-R/Private Eye.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/private_eye.bin
# copying kaboom.bin from roms/HC ROMS/BY ALPHABET/H-R/Kaboom!.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/kaboom.bin
# copying ice_hockey.bin from roms/HC ROMS/BY ALPHABET/H-R/Ice Hockey.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/ice_hockey.bin
# copying montezuma_revenge.bin from roms/HC ROMS/BY ALPHABET/H-R/Montezuma's Revenge - Featuring Panama Joe.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying lost_luggage.bin from roms/HC ROMS/BY ALPHABET/H-R/Lost Luggage [no opening scene].bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/lost_luggage.bin
# copying qbert.bin from roms/HC ROMS/BY ALPHABET/H-R/Q-bert.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/qbert.bin
# copying journey_escape.bin from roms/HC ROMS/BY ALPHABET/H-R/Journey Escape.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/journey_escape.bin
# copying kangaroo.bin from roms/HC ROMS/BY ALPHABET/H-R/Kangaroo.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/kangaroo.bin
# copying hero.bin from roms/HC ROMS/BY ALPHABET/H-R/H.E.R.O..bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/hero.bin
# copying krull.bin from roms/HC ROMS/BY ALPHABET/H-R/Krull.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/krull.bin
# copying name_this_game.bin from roms/HC ROMS/BY ALPHABET/H-R/Name This Game.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/name_this_game.bin
# copying pooyan.bin from roms/HC ROMS/BY ALPHABET/H-R/Pooyan.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/pooyan.bin
# copying koolaid.bin from roms/HC ROMS/BY ALPHABET/H-R/Kool-Aid Man.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/koolaid.bin
# copying riverraid.bin from roms/HC ROMS/BY ALPHABET/H-R/River Raid.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/riverraid.bin
# copying pitfall.bin from roms/HC ROMS/BY ALPHABET/H-R/Pitfall! - Pitfall Harry's Jungle Adventure.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/pitfall.bin
# copying phoenix.bin from roms/HC ROMS/BY ALPHABET/H-R/Phoenix.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/phoenix.bin
# copying jamesbond.bin from roms/HC ROMS/BY ALPHABET/H-R/James Bond 007.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/jamesbond.bin
# copying space_invaders.bin from roms/HC ROMS/BY ALPHABET/S-Z/Space Invaders.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/space_invaders.bin
# copying seaquest.bin from roms/HC ROMS/BY ALPHABET/S-Z/Seaquest.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/seaquest.bin
# copying solaris.bin from roms/HC ROMS/BY ALPHABET/S-Z/Solaris.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/solaris.bin
# copying surround.bin from roms/HC ROMS/BY ALPHABET/S-Z/Surround - Chase.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/surround.bin
# copying pong.bin from roms/HC ROMS/BY ALPHABET/S-Z/Video Olympics - Pong Sports.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/pong.bin
# copying video_pinball.bin from roms/HC ROMS/BY ALPHABET/S-Z/Video Pinball - Arcade Pinball.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/video_pinball.bin
# copying time_pilot.bin from roms/HC ROMS/BY ALPHABET/S-Z/Time Pilot.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/time_pilot.bin
# copying zaxxon.bin from roms/HC ROMS/BY ALPHABET/S-Z/Zaxxon.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/zaxxon.bin
# copying star_gunner.bin from roms/HC ROMS/BY ALPHABET/S-Z/Stargunner.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/star_gunner.bin
# copying yars_revenge.bin from roms/HC ROMS/BY ALPHABET/S-Z/Yars' Revenge.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/yars_revenge.bin
# copying up_n_down.bin from roms/HC ROMS/BY ALPHABET/S-Z/Up 'n Down.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/up_n_down.bin
# copying tutankham.bin from roms/HC ROMS/BY ALPHABET/S-Z/Tutankham.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/tutankham.bin
# copying tennis.bin from roms/HC ROMS/BY ALPHABET/S-Z/Tennis.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/tennis.bin
# copying venture.bin from roms/HC ROMS/BY ALPHABET/S-Z/Venture.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/venture.bin
# copying wizard_of_wor.bin from roms/HC ROMS/BY ALPHABET/S-Z/Wizard of Wor.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying skiing.bin from roms/HC ROMS/BY ALPHABET/S-Z/Skiing.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/skiing.bin
# copying trondead.bin from roms/HC ROMS/BY ALPHABET/S-Z/TRON - Deadly Discs.bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/trondead.bin
# copying adventure.bin from roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/adventure.bin
# copying laser_gates.bin from roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/laser_gates.bin
# copying pacman.bin from roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/pacman.bin
# copying sir_lancelot.bin from roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/sir_lancelot.bin
# copying king_kong.bin from roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/king_kong.bin
# copying mr_do.bin from roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Mr. Do! (1983) (CBS Electronics - Individeo, Ed English) (4L4478) (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/mr_do.bin
# copying keystone_kapers.bin from roms/HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/keystone_kapers.bin
# copying asterix.bin from roms/ROMS/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696).bin to /home/shervin/.local/lib/python3.8/site-packages/atari_py/atari_roms/asterix.bin

# %% [markdown]
# ## Making Environment and the DQNetwork

# %%
import gym
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math
import os.path
import torch.nn as nn
import torch.optim as optim
import time

# %%
env = gym.make('Pong-v4')

# %%
plt.style.use('ggplot')
# if gpu is to be used
use_cuda = torch.cuda.is_available()

device = torch.device("cuda:0" if use_cuda else "cpu")
Tensor = torch.Tensor
LongTensor = torch.LongTensor

directory = './PongVideos/'
#env = gym.wrappers.Monitor(env, directory, force=True, video_callable=lambda episode_id: episode_id%20==0)

seed_value = 23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
if use_cuda:
  print(torch.cuda.get_device_name('cuda:0'))

# %%
state = env.reset()

for i in range(1000):
    action = env.action_space.sample()
    new_state, reward, done, info = env.step(action)
    print(f'info: {info}')
    frame = cv2.cvtColor(new_state, cv2.COLOR_RGB2GRAY)
    frame = cv2.resize(frame, (84,84), interpolation = cv2.INTER_AREA)
    plt.imshow(frame)
    plt.show()
# Out:
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# info: {'ale.lives': 0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       8 frame = cv2.resize(frame, (84,84), interpolation = cv2.INTER_AREA)
#       9 plt.imshow(frame)
# ---> 10 plt.show()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File <decorator-gen-2>:2, in __call__(self, obj)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:646, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     644         renderer.draw_image(gc, l, b, im, trans)
#     645 else:
# --> 646     im, l, b, trans = self.make_image(
#     647         renderer, renderer.get_image_magnification())
#     648     if im is not None:
#     649         renderer.draw_image(gc, l, b, im)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:956, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     953 transformed_bbox = TransformedBbox(bbox, trans)
#     954 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     955         else self.figure.bbox)
# --> 956 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     957                         magnification, unsampled=unsampled)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:348, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     343 if A.size == 0:
#     344     raise RuntimeError("_make_image must get a non-empty image. "
#     345                        "Your Artist's draw method must filter before "
#     346                        "this method is called.")
# --> 348 clipped_bbox = Bbox.intersection(out_bbox, clip_bbox)
#     350 if clipped_bbox is None:
#     351     return None, 0, 0, None
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:679, in BboxBase.intersection(bbox1, bbox2)
#     673 @staticmethod
#     674 def intersection(bbox1, bbox2):
#     675     """
#     676     Return the intersection of *bbox1* and *bbox2* if they intersect, or
#     677     None if they don't.
#     678     """
# --> 679     x0 = np.maximum(bbox1.xmin, bbox2.xmin)
#     680     x1 = np.minimum(bbox1.xmax, bbox2.xmax)
#     681     y0 = np.maximum(bbox1.ymin, bbox2.ymin)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:329, in BboxBase.xmin(self)
#     326 @property
#     327 def xmin(self):
#     328     """The left edge of the bounding box."""
# --> 329     return np.min(self.get_points()[:, 0])
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1129, in TransformedBbox.get_points(self)
#    1125 p = self._bbox.get_points()
#    1126 # Transform all four points, then make a new bounding box
#    1127 # from the result, taking care to make the orientation the
#    1128 # same.
# -> 1129 points = self._transform.transform(
#    1130     [[p[0, 0], p[0, 1]],
#    1131      [p[1, 0], p[0, 1]],
#    1132      [p[0, 0], p[1, 1]],
#    1133      [p[1, 0], p[1, 1]]])
#    1134 points = np.ma.filled(points, 0.0)
#    1136 xs = min(points[:, 0]), max(points[:, 0])
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1503, in Transform.transform(self, values)
#    1500 values = values.reshape((-1, self.input_dims))
#    1502 # Transform the values
# -> 1503 res = self.transform_affine(self.transform_non_affine(values))
#    1505 # Convert the result back to the shape of the input values.
#    1506 if ndim == 0:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:2419, in CompositeGenericTransform.transform_affine(self, points)
#    2417 def transform_affine(self, points):
#    2418     # docstring inherited
# -> 2419     return self.get_affine().transform(points)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:2447, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
#    2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2447                            self._a.get_affine().get_matrix()))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:2659, in BboxTransformFrom.get_matrix(self)
#    2656 def get_matrix(self):
#    2657     # docstring inherited
#    2658     if self._invalid:
# -> 2659         inl, inb, inw, inh = self._boxin.bounds
#    2660         if DEBUG and (inw == 0 or inh == 0):
#    2661             raise ValueError("Transforming from a singular bounding box.")
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:395, in BboxBase.bounds(self)
#     392 @property
#     393 def bounds(self):
#     394     """Return (:attr:`x0`, :attr:`y0`, :attr:`width`, :attr:`height`)."""
# --> 395     (x0, y0), (x1, y1) = self.get_points()
#     396     return (x0, y0, x1 - x0, y1 - y0)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1129, in TransformedBbox.get_points(self)
#    1125 p = self._bbox.get_points()
#    1126 # Transform all four points, then make a new bounding box
#    1127 # from the result, taking care to make the orientation the
#    1128 # same.
# -> 1129 points = self._transform.transform(
#    1130     [[p[0, 0], p[0, 1]],
#    1131      [p[1, 0], p[0, 1]],
#    1132      [p[0, 0], p[1, 1]],
#    1133      [p[1, 0], p[1, 1]]])
#    1134 points = np.ma.filled(points, 0.0)
#    1136 xs = min(points[:, 0]), max(points[:, 0])
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1798, in AffineBase.transform(self, values)
#    1796 def transform(self, values):
#    1797     # docstring inherited
# -> 1798     return self.transform_affine(values)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1863, in Affine2DBase.transform_affine(self, points)
#    1862 def transform_affine(self, points):
# -> 1863     mtx = self.get_matrix()
#    1864     if isinstance(points, np.ma.MaskedArray):
#    1865         tpoints = affine_transform(points.data, mtx)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:2314, in BlendedAffine2D.get_matrix(self)
#    2311 def get_matrix(self):
#    2312     # docstring inherited
#    2313     if self._invalid:
# -> 2314         if self._x == self._y:
#    2315             self._mtx = self._x.get_matrix()
#    2316         else:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1793, in AffineBase.__eq__(self, other)
#    1791 def __eq__(self, other):
#    1792     if getattr(other, "is_affine", False) and hasattr(other, "get_matrix"):
# -> 1793         return np.all(self.get_matrix() == other.get_matrix())
#    1794     return NotImplemented
#
# File <__array_function__ internals>:180, in all(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2487, in all(a, axis, out, keepdims, where)
#    2404 @array_function_dispatch(_all_dispatcher)
#    2405 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2406     """
#    2407     Test whether all array elements along a given axis evaluate to True.
#    2408
#    (...)
#    2485
#    2486     """
# -> 2487     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#    2488                           keepdims=keepdims, where=where)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
###### PARAMS ######
learning_rate = 0.0001
num_episodes = 500
gamma = 0.99

hidden_layer = 512

replay_mem_size = 50000
batch_size = 32

update_target_frequency = 2000

double_dqn = True

egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 10000

report_interval = 10
score_to_solve = 18

clip_error = True
normalize_image = True

file2save = 'pong_save.pth'
save_model_frequency = 10000
resume_previous_training = False

# %%
state = env.reset()
action = env.action_space.sample()
new_state, reward, done, info = env.step(action)
trans = (state, action, new_state,reward,done)
trans

# %%
import sys
print(sys.getsizeof(trans))
# Out:
# 80

# %%
number_of_inputs = env.observation_space.shape[0]
number_of_outputs = env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
def load_model():
    return torch.load(file2save)

def save_model(model):
    torch.save(model.state_dict(), file2save)

# %%
def preprocess_frame(frame):
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    frame = cv2.resize(frame, (84,84), interpolation = cv2.INTER_AREA)
    frame = np.expand_dims(frame,axis=2)
    frame = frame.transpose((2,0,1))
    frame = torch.from_numpy(frame)
    frame = frame.to(device, dtype=torch.float32)
    frame = frame.unsqueeze(1)
    
    return frame

# %%
state = env.reset()
for i in range(900):
    action = env.action_space.sample()
    new_state, reward, done, info = env.step(action)
    frame = cv2.cvtColor(new_state, cv2.COLOR_RGB2GRAY)
    frame = cv2.resize(frame, (84,84), interpolation = cv2.INTER_AREA)
    plt.imshow(frame)
    plt.show()
    if done:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       6 frame = cv2.resize(frame, (84,84), interpolation = cv2.INTER_AREA)
#       7 plt.imshow(frame)
# ----> 8 plt.show()
#       9 if done:
#      10     break
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File <decorator-gen-2>:2, in __call__(self, obj)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py:2299, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
# -> 2299         bbox_inches = self.figure.get_tightbbox(
#    2300             renderer, bbox_extra_artists=bbox_extra_artists)
#    2301         if pad_inches is None:
#    2302             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/figure.py:1641, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1637 if ax.get_visible():
#    1638     # some axes don't take the bbox_extra_artists kwarg so we
#    1639     # need this conditional....
#    1640     try:
# -> 1641         bbox = ax.get_tightbbox(
#    1642             renderer, bbox_extra_artists=bbox_extra_artists)
#    1643     except TypeError:
#    1644         bbox = ax.get_tightbbox(renderer)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:4619, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4617 if self.xaxis.get_visible():
#    4618     try:
# -> 4619         bb_xaxis = self.xaxis.get_tightbbox(
#    4620             renderer, for_layout_only=for_layout_only)
#    4621     except TypeError:
#    4622         # in case downstream library has redefined axis:
#    4623         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axis.py:1105, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1101     return
#    1103 ticks_to_draw = self._update_ticks()
# -> 1105 self._update_label_position(renderer)
#    1107 # go back to just this axis's tick labels
#    1108 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1109             ticks_to_draw, renderer)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axis.py:2083, in XAxis._update_label_position(self, renderer)
#    2079     return
#    2081 # get bounding boxes for this axis and any siblings
#    2082 # that have been set by `fig.align_xlabels()`
# -> 2083 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2085 x, y = self.label.get_position()
#    2086 if self.label_position == 'bottom':
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axis.py:1880, in Axis._get_tick_boxes_siblings(self, renderer)
#    1878 for ax in grouper.get_siblings(self.axes):
#    1879     axis = getattr(ax, f"{axis_name}axis")
# -> 1880     ticks_to_draw = axis._update_ticks()
#    1881     tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1882     bboxes.extend(tlb)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axis.py:1046, in Axis._update_ticks(self)
#    1041 """
#    1042 Update ticks (position and labels) using the current data interval of
#    1043 the axes.  Return the list of ticks that will be drawn.
#    1044 """
#    1045 major_locs = self.get_majorticklocs()
# -> 1046 major_labels = self.major.formatter.format_ticks(major_locs)
#    1047 major_ticks = self.get_major_ticks(len(major_locs))
#    1048 self.major.formatter.set_locs(major_locs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/ticker.py:223, in Formatter.format_ticks(self, values)
#     221 def format_ticks(self, values):
#     222     """Return the tick labels for all the ticks at once."""
# --> 223     self.set_locs(values)
#     224     return [self(value, i) for i, value in enumerate(values)]
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/ticker.py:712, in ScalarFormatter.set_locs(self, locs)
#     710     self._compute_offset()
#     711 self._set_order_of_magnitude()
# --> 712 self._set_format()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/ticker.py:809, in ScalarFormatter._set_format(self)
#     807 sigfigs = max(0, 3 - loc_range_oom)
#     808 # refined estimate:
# --> 809 thresh = 1e-3 * 10 ** loc_range_oom
#     810 while sigfigs >= 0:
#     811     if np.abs(locs - np.round(locs, decimals=sigfigs)).max() < thresh:
#
# KeyboardInterrupt:

# %%
def plot_results():
    plt.figure(figsize=(12,5))
    plt.title("Rewards")
    plt.plot(rewards_total, alpha=0.6, color='red')
    plt.savefig("Pong-results.png")
    plt.close()

# %%
class ExperienceReplay(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
 
    def push(self, state, action, new_state, reward, done):
        transition = (state, action, new_state, reward, done)
        
        if self.position >= len(self.memory):
            self.memory.append(transition)
        else:
            self.memory[self.position] = transition
        
        self.position = ( self.position + 1 ) % self.capacity
        
        
    def sample(self, batch_size):
        return zip(*random.sample(self.memory, batch_size))
        
        
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1)
        
        self.advantage1 = nn.Linear(7*7*64,hidden_layer)
        self.advantage2 = nn.Linear(hidden_layer, number_of_outputs)
        
        self.value1 = nn.Linear(7*7*64,hidden_layer)
        self.value2 = nn.Linear(hidden_layer,1)

        #self.activation = nn.Tanh()
        self.activation = nn.ReLU()
        
        
    def forward(self, x):
        
        if normalize_image:
            x = x / 255
        
        output_conv = self.conv1(x)
        output_conv = self.activation(output_conv)
        output_conv = self.conv2(output_conv)
        output_conv = self.activation(output_conv)
        output_conv = self.conv3(output_conv)
        output_conv = self.activation(output_conv)
        
        output_conv = output_conv.view(output_conv.size(0), -1) # flatten
        
        output_advantage = self.advantage1(output_conv)
        output_advantage = self.activation(output_advantage)
        output_advantage = self.advantage2(output_advantage)
        
        output_value = self.value1(output_conv)
        output_value = self.activation(output_value)
        output_value = self.value2(output_value)
        
        output_final = output_value + output_advantage - output_advantage.mean()

        return output_final

# %%
class QNet_Agent(object):
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.target_nn = NeuralNetwork().to(device)

        self.loss_func = nn.MSELoss()
        #self.loss_func = nn.SmoothL1Loss()
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        #self.optimizer = optim.RMSprop(params=mynn.parameters(), lr=learning_rate)
        
        self.number_of_frames = 0
        
        if resume_previous_training and os.path.exists(file2save):
            print("Loading previously saved model ... ")
            self.nn.load_state_dict(load_model())
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1).item()
        
        if random_for_egreedy > epsilon:      
            
            with torch.no_grad():
                
                state = preprocess_frame(state)
                action_from_nn = self.nn(state)
                
                action = torch.max(action_from_nn,1)[1]
                action = action.item()        
        else:
            action = env.action_space.sample()
        
        return action
    
    def optimize(self):
        
        if (len(memory) < batch_size):
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = [ preprocess_frame(frame) for frame in state ] 
        state = torch.cat(state)
        
        new_state = [ preprocess_frame(frame) for frame in new_state ] 
        new_state = torch.cat(new_state)

        reward = Tensor(reward).to(device)
        action = LongTensor(action).to(device)
        done = Tensor(done).to(device)


        if double_dqn:
            new_state_indexes = self.nn(new_state).detach()
            max_new_state_indexes = torch.max(new_state_indexes, 1)[1]  
            
            new_state_values = self.target_nn(new_state).detach()
            max_new_state_values = new_state_values.gather(1, max_new_state_indexes.unsqueeze(1)).squeeze(1)
        else:
            new_state_values = self.target_nn(new_state).detach()
            max_new_state_values = torch.max(new_state_values, 1)[0]
        
        
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.data.clamp_(-1,1)
        
        self.optimizer.step()
        
        if self.number_of_frames % update_target_frequency == 0:
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        if self.number_of_frames % save_model_frequency == 0:
            save_model(self.nn)
        
        self.number_of_frames += 1
        
        #Q[state, action] = reward + gamma * torch.max(Q[new_state])

# %%
memory = ExperienceReplay(replay_mem_size)
qnet_agent = QNet_Agent()

rewards_total = []

frames_total = 0 
solved_after = 0
solved = False

start_time = time.time()

# %%
for i_episode in range(num_episodes):
    
    state = env.reset()
    
    score = 0
    #for step in range(100):
    while True:
        
        frames_total += 1
        
        epsilon = calculate_epsilon(frames_total)
        
        #action = env.action_space.sample()
        action = qnet_agent.select_action(state, epsilon)
        
        new_state, reward, done, info = env.step(action)
        
        score += reward

        memory.push(state, action, new_state, reward, done)
        qnet_agent.optimize()
        
        state = new_state
        
        if done:
            rewards_total.append(score)
            
            mean_reward_100 = sum(rewards_total[-100:])/100
            
            if (mean_reward_100 > score_to_solve and solved == False):
                print("SOLVED! After %i episodes " % i_episode)
                solved_after = i_episode
                solved = True
            
            if (i_episode % report_interval == 0 and i_episode > 0):
                
                plot_results()
                
                print("\n*** Episode %i *** \
                      \nAv.reward: [last %i]: %.2f, [last 100]: %.2f, [all]: %.2f \
                      \nepsilon: %.2f, frames_total: %i" 
                  % 
                  ( i_episode,
                    report_interval,
                    sum(rewards_total[-report_interval:])/report_interval,
                    mean_reward_100,
                    sum(rewards_total)/len(rewards_total),
                    epsilon,
                    frames_total
                          ) 
                  )
                  
                elapsed_time = time.time() - start_time
                print("Elapsed time: ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))



            break
        

print("\n\n\n\nAverage reward: %.2f" % (sum(rewards_total)/num_episodes))
print("Average reward (last 100 episodes): %.2f" % (sum(rewards_total[-100:])/100))
if solved:
    print("Solved after %i episodes" % solved_after)


env.close()
env.env.close()
# Out:
# *** Episode 10 ***
# Av.reward: [last 10]: -20.40, [last 100]: -2.23, [all]: -20.27
# epsilon: 0.25, frames_total: 13206
# Elapsed time:  00:30:51
#
# *** Episode 20 ***
# Av.reward: [last 10]: -20.10, [last 100]: -4.24, [all]: -20.19
# epsilon: 0.07, frames_total: 26460
# Elapsed time:  00:55:51
